# %% [markdown]
# # Beginner Tutorials - 1. ML basics
# # 6. Overfitting and Underfitting
# 1. IMDB 데이터셋 다운로드
# - 과대적합 예제
#  - 기준 모델 만들기
#  - 작은 모델 만들기
#  - 큰 모델 만들기
#  - 훈련 손실과 검증 손실 그래프 그리기
# - 과대적합을 방지하기 위한 전략
#  - 가중치를 규제하기
#  - 드롭아웃 추가하기
#
# URL : https://www.tensorflow.org/alpha/tutorials/keras/overfit_and_underfit <br>
# GitHub : https://github.com/tensorflow/docs/blob/master/site/ko/alpha/tutorials/keras/overfit_and_underfit.ipynb

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# !pip install -q tensorflow==2.0.0-alpha0
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 1.13.1

# %% [markdown]
# ## 1. IMDB 데이터셋 다운로드

# %%
NUM_WORDS = 10000

(train_data, train_labels), (test_data, test_labels) = keras.datasets.imdb.load_data(num_words = NUM_WORDS)

def multi_hot_sequences(sequences, dimension):
    results = np.zeros((len(sequences), dimension))
    for i, word_indices in enumerate(sequences):
        results[i, word_indices] = 1.
    return results

train_data = multi_hot_sequences(train_data, dimension=NUM_WORDS)
test_data = multi_hot_sequences(test_data, dimension=NUM_WORDS)

# %%
train_data.shape, test_data.shape
# Out:
# ((25000, 10000), (25000, 10000))

# %%
plt.plot(train_data[0])

# %%
train_data[0]
# Out:
# array([0., 1., 1., ..., 0., 0., 0.])

# %% [markdown]
# ## 2. 과대적합 예제
#
# ### 기준 모델 만들기

# %%
baseline_model = keras.Sequential([
    keras.layers.Dense(16, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

baseline_model.compile(optimizer='adam',
                      loss='binary_crossentropy',
                      metrics=['acc','binary_crossentropy'])

baseline_model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\la\Anaconda3\envs\py36\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                160016
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseline_history = baseline_model.fit(train_data, 
                                     train_labels,
                                     epochs=20,
                                     batch_size=512,
                                     validation_data=(test_data,test_labels),
                                     verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# WARNING:tensorflow:From C:\Users\la\Anaconda3\envs\py36\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/20
#  - 8s - loss: 0.4728 - acc: 0.8043 - binary_crossentropy: 0.4728 - val_loss: 0.3234 - val_acc: 0.8787 - val_binary_crossentropy: 0.3234
# Epoch 2/20
#  - 5s - loss: 0.2396 - acc: 0.9137 - binary_crossentropy: 0.2396 - val_loss: 0.2832 - val_acc: 0.8882 - val_binary_crossentropy: 0.2832
# Epoch 3/20
#  - 4s - loss: 0.1752 - acc: 0.9384 - binary_crossentropy: 0.1752 - val_loss: 0.2968 - val_acc: 0.8828 - val_binary_crossentropy: 0.2968
# Epoch 4/20
#  - 4s - loss: 0.1420 - acc: 0.9511 - binary_crossentropy: 0.1420 - val_loss: 0.3421 - val_acc: 0.8701 - val_binary_crossentropy: 0.3421
# Epoch 5/20
#  - 4s - loss: 0.1164 - acc: 0.9612 - binary_crossentropy: 0.1164 - val_loss: 0.3486 - val_acc: 0.8729 - val_binary_crossentropy: 0.3486
# Epoch 6/20
#  - 4s - loss: 0.0950 - acc: 0.9708 - binary_crossentropy: 0.0950 - val_loss: 0.3819 - val_acc: 0.8693 - val_binary_crossentropy: 0.3819
# Epoch 7/20
#  - 4s - loss: 0.0785 - acc: 0.9766 - binary_crossentropy: 0.0785 - val_loss: 0.4204 - val_acc: 0.8652 - val_binary_crossentropy: 0.4204
# Epoch 8/20
#  - 4s - loss: 0.0663 - acc: 0.9819 - binary_crossentropy: 0.0663 - val_loss: 0.4614 - val_acc: 0.8613 - val_binary_crossentropy: 0.4614
# Epoch 9/20
#  - 4s - loss: 0.0530 - acc: 0.9873 - binary_crossentropy: 0.0530 - val_loss: 0.5017 - val_acc: 0.8605 - val_binary_crossentropy: 0.5017
# Epoch 10/20
#  - 4s - loss: 0.0443 - acc: 0.9899 - binary_crossentropy: 0.0443 - val_loss: 0.5461 - val_acc: 0.8566 - val_binary_crossentropy: 0.5461
# Epoch 11/20
#  - 4s - loss: 0.0351 - acc: 0.9936 - binary_crossentropy: 0.0351 - val_loss: 0.5932 - val_acc: 0.8535 - val_binary_crossentropy: 0.5932
# Epoch 12/20
#  - 4s - loss: 0.0276 - acc: 0.9952 - binary_crossentropy: 0.0276 - val_loss: 0.6333 - val_acc: 0.8539 - val_binary_crossentropy: 0.6333
# Epoch 13/20
#  - 4s - loss: 0.0221 - acc: 0.9972 - binary_crossentropy: 0.0221 - val_loss: 0.6838 - val_acc: 0.8506 - val_binary_crossentropy: 0.6838
# Epoch 14/20
#  - 4s - loss: 0.0170 - acc: 0.9986 - binary_crossentropy: 0.0170 - val_loss: 0.7246 - val_acc: 0.8506 - val_binary_crossentropy: 0.7246
# Epoch 15/20
#  - 4s - loss: 0.0132 - acc: 0.9990 - binary_crossentropy: 0.0132 - val_loss: 0.7500 - val_acc: 0.8513 - val_binary_crossentropy: 0.7500
# Epoch 16/20
#  - 4s - loss: 0.0104 - acc: 0.9994 - binary_crossentropy: 0.0104 - val_loss: 0.7894 - val_acc: 0.8500 - val_binary_crossentropy: 0.7894
# Epoch 17/20
#  - 4s - loss: 0.0086 - acc: 0.9996 - binary_crossentropy: 0.0086 - val_loss: 0.8164 - val_acc: 0.8507 - val_binary_crossentropy: 0.8164
# Epoch 18/20
#  - 4s - loss: 0.0069 - acc: 0.9996 - binary_crossentropy: 0.0069 - val_loss: 0.8500 - val_acc: 0.8494 - val_binary_crossentropy: 0.8500
# Epoch 19/20
#  - 4s - loss: 0.0057 - acc: 0.9997 - binary_crossentropy: 0.0057 - val_loss: 0.8805 - val_acc: 0.8490 - val_binary_crossentropy: 0.8805
# Epoch 20/20
#  - 4s - loss: 0.0048 - acc: 0.9997 - binary_crossentropy: 0.0048 - val_loss: 0.9061 - val_acc: 0.8482 - val_binary_crossentropy: 0.9061

# %% [markdown]
# ### 작은 모델 만들기

# %%
smaller_model = keras.Sequential([
    keras.layers.Dense(4, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(4, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

smaller_model.compile(optimizer='adam',
                      loss='binary_crossentropy',
                      metrics=['accuracy', 'binary_crossentropy'])

smaller_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 4)                 40004
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 40,029
# Trainable params: 40,029
# Non-trainable params: 0
# _________________________________________________________________

# %%
smaller_history = smaller_model.fit(train_data,
                                    train_labels,
                                    epochs=20,
                                    batch_size=512,
                                    validation_data=(test_data, test_labels),
                                    verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 5s - loss: 0.6057 - acc: 0.6341 - binary_crossentropy: 0.6057 - val_loss: 0.5305 - val_acc: 0.7686 - val_binary_crossentropy: 0.5305
# Epoch 2/20
#  - 4s - loss: 0.4811 - acc: 0.8437 - binary_crossentropy: 0.4811 - val_loss: 0.4818 - val_acc: 0.8420 - val_binary_crossentropy: 0.4818
# Epoch 3/20
#  - 5s - loss: 0.4297 - acc: 0.8998 - binary_crossentropy: 0.4297 - val_loss: 0.4628 - val_acc: 0.8578 - val_binary_crossentropy: 0.4628
# Epoch 4/20
#  - 5s - loss: 0.3962 - acc: 0.9237 - binary_crossentropy: 0.3962 - val_loss: 0.4477 - val_acc: 0.8750 - val_binary_crossentropy: 0.4477
# Epoch 5/20
#  - 4s - loss: 0.3715 - acc: 0.9383 - binary_crossentropy: 0.3715 - val_loss: 0.4560 - val_acc: 0.8586 - val_binary_crossentropy: 0.4560
# Epoch 6/20
#  - 4s - loss: 0.3482 - acc: 0.9501 - binary_crossentropy: 0.3482 - val_loss: 0.4361 - val_acc: 0.8752 - val_binary_crossentropy: 0.4361
# Epoch 7/20
#  - 4s - loss: 0.3278 - acc: 0.9584 - binary_crossentropy: 0.3278 - val_loss: 0.4421 - val_acc: 0.8698 - val_binary_crossentropy: 0.4421
# Epoch 8/20
#  - 4s - loss: 0.3103 - acc: 0.9644 - binary_crossentropy: 0.3103 - val_loss: 0.4446 - val_acc: 0.8675 - val_binary_crossentropy: 0.4446
# Epoch 9/20
#  - 4s - loss: 0.2941 - acc: 0.9700 - binary_crossentropy: 0.2941 - val_loss: 0.4484 - val_acc: 0.8664 - val_binary_crossentropy: 0.4484
# Epoch 10/20
#  - 4s - loss: 0.2798 - acc: 0.9740 - binary_crossentropy: 0.2798 - val_loss: 0.4587 - val_acc: 0.8646 - val_binary_crossentropy: 0.4587
# Epoch 11/20
#  - 4s - loss: 0.2666 - acc: 0.9772 - binary_crossentropy: 0.2666 - val_loss: 0.4655 - val_acc: 0.8635 - val_binary_crossentropy: 0.4655
# Epoch 12/20
#  - 4s - loss: 0.2546 - acc: 0.9800 - binary_crossentropy: 0.2546 - val_loss: 0.4791 - val_acc: 0.8612 - val_binary_crossentropy: 0.4791
# Epoch 13/20
#  - 4s - loss: 0.2433 - acc: 0.9813 - binary_crossentropy: 0.2433 - val_loss: 0.4971 - val_acc: 0.8578 - val_binary_crossentropy: 0.4971
# Epoch 14/20
#  - 4s - loss: 0.2330 - acc: 0.9828 - binary_crossentropy: 0.2330 - val_loss: 0.4916 - val_acc: 0.8606 - val_binary_crossentropy: 0.4916
# Epoch 15/20
#  - 4s - loss: 0.2237 - acc: 0.9841 - binary_crossentropy: 0.2237 - val_loss: 0.4983 - val_acc: 0.8590 - val_binary_crossentropy: 0.4983
# Epoch 16/20
#  - 4s - loss: 0.2150 - acc: 0.9852 - binary_crossentropy: 0.2150 - val_loss: 0.5005 - val_acc: 0.8589 - val_binary_crossentropy: 0.5005
# Epoch 17/20
#  - 4s - loss: 0.2070 - acc: 0.9856 - binary_crossentropy: 0.2070 - val_loss: 0.5009 - val_acc: 0.8600 - val_binary_crossentropy: 0.5009
# Epoch 18/20
#  - 4s - loss: 0.1997 - acc: 0.9860 - binary_crossentropy: 0.1997 - val_loss: 0.5232 - val_acc: 0.8569 - val_binary_crossentropy: 0.5232
# Epoch 19/20
#  - 4s - loss: 0.1929 - acc: 0.9864 - binary_crossentropy: 0.1929 - val_loss: 0.5294 - val_acc: 0.8568 - val_binary_crossentropy: 0.5294
# Epoch 20/20
#  - 4s - loss: 0.1866 - acc: 0.9866 - binary_crossentropy: 0.1866 - val_loss: 0.5445 - val_acc: 0.8568 - val_binary_crossentropy: 0.5445

# %%
bigger_model = keras.models.Sequential([
    keras.layers.Dense(512, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

bigger_model.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy','binary_crossentropy'])

bigger_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 512)               5120512
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 5,383,681
# Trainable params: 5,383,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
bigger_history = bigger_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 5s - loss: 0.3488 - acc: 0.8465 - binary_crossentropy: 0.3488 - val_loss: 0.3076 - val_acc: 0.8730 - val_binary_crossentropy: 0.3076
# Epoch 2/20
#  - 4s - loss: 0.1476 - acc: 0.9452 - binary_crossentropy: 0.1476 - val_loss: 0.3253 - val_acc: 0.8741 - val_binary_crossentropy: 0.3253
# Epoch 3/20
#  - 4s - loss: 0.0478 - acc: 0.9854 - binary_crossentropy: 0.0478 - val_loss: 0.4483 - val_acc: 0.8672 - val_binary_crossentropy: 0.4483
# Epoch 4/20
#  - 5s - loss: 0.0078 - acc: 0.9985 - binary_crossentropy: 0.0078 - val_loss: 0.5922 - val_acc: 0.8636 - val_binary_crossentropy: 0.5922
# Epoch 5/20
#  - 5s - loss: 0.0013 - acc: 0.9999 - binary_crossentropy: 0.0013 - val_loss: 0.6713 - val_acc: 0.8690 - val_binary_crossentropy: 0.6713
# Epoch 6/20
#  - 4s - loss: 4.1353e-04 - acc: 0.9999 - binary_crossentropy: 4.1353e-04 - val_loss: 0.7195 - val_acc: 0.8677 - val_binary_crossentropy: 0.7195
# Epoch 7/20
#  - 4s - loss: 1.7456e-04 - acc: 1.0000 - binary_crossentropy: 1.7456e-04 - val_loss: 0.7422 - val_acc: 0.8686 - val_binary_crossentropy: 0.7422
# Epoch 8/20
#  - 4s - loss: 1.0362e-04 - acc: 1.0000 - binary_crossentropy: 1.0362e-04 - val_loss: 0.7633 - val_acc: 0.8686 - val_binary_crossentropy: 0.7633
# Epoch 9/20
#  - 5s - loss: 7.8670e-05 - acc: 1.0000 - binary_crossentropy: 7.8670e-05 - val_loss: 0.7794 - val_acc: 0.8689 - val_binary_crossentropy: 0.7794
# Epoch 10/20
#  - 5s - loss: 6.2736e-05 - acc: 1.0000 - binary_crossentropy: 6.2736e-05 - val_loss: 0.7930 - val_acc: 0.8689 - val_binary_crossentropy: 0.7930
# Epoch 11/20
#  - 5s - loss: 5.1281e-05 - acc: 1.0000 - binary_crossentropy: 5.1281e-05 - val_loss: 0.8051 - val_acc: 0.8690 - val_binary_crossentropy: 0.8051
# Epoch 12/20
#  - 5s - loss: 4.2984e-05 - acc: 1.0000 - binary_crossentropy: 4.2984e-05 - val_loss: 0.8154 - val_acc: 0.8689 - val_binary_crossentropy: 0.8154
# Epoch 13/20
#  - 5s - loss: 3.6411e-05 - acc: 1.0000 - binary_crossentropy: 3.6411e-05 - val_loss: 0.8245 - val_acc: 0.8690 - val_binary_crossentropy: 0.8245
# Epoch 14/20
#  - 4s - loss: 3.1356e-05 - acc: 1.0000 - binary_crossentropy: 3.1356e-05 - val_loss: 0.8336 - val_acc: 0.8691 - val_binary_crossentropy: 0.8336
# Epoch 15/20
#  - 4s - loss: 2.7230e-05 - acc: 1.0000 - binary_crossentropy: 2.7230e-05 - val_loss: 0.8411 - val_acc: 0.8695 - val_binary_crossentropy: 0.8411
# Epoch 16/20
#  - 5s - loss: 2.3915e-05 - acc: 1.0000 - binary_crossentropy: 2.3915e-05 - val_loss: 0.8487 - val_acc: 0.8696 - val_binary_crossentropy: 0.8487
# Epoch 17/20
#  - 5s - loss: 2.1114e-05 - acc: 1.0000 - binary_crossentropy: 2.1114e-05 - val_loss: 0.8555 - val_acc: 0.8693 - val_binary_crossentropy: 0.8555
# Epoch 18/20
#  - 5s - loss: 1.8763e-05 - acc: 1.0000 - binary_crossentropy: 1.8763e-05 - val_loss: 0.8621 - val_acc: 0.8694 - val_binary_crossentropy: 0.8621
# Epoch 19/20
#  - 5s - loss: 1.6779e-05 - acc: 1.0000 - binary_crossentropy: 1.6779e-05 - val_loss: 0.8679 - val_acc: 0.8693 - val_binary_crossentropy: 0.8679
# Epoch 20/20
#  - 5s - loss: 1.5092e-05 - acc: 1.0000 - binary_crossentropy: 1.5092e-05 - val_loss: 0.8737 - val_acc: 0.8694 - val_binary_crossentropy: 0.8737

# %% [markdown]
# ### 훈련 손실과 검증 손실 그래프 그리기

# %%
def plot_history(histories, key='binary_crossentropy'):
    plt.figure(figsize=(16,10))
    
    for name, history in histories:
        val=plt.plot(history.epoch, history.history['val_'+key],
                    '--', label=name.title()+' Val')
        plt.plot(history.epoch, history.history[key], color=val[0].get_color(), 
                 label=name.title() + ' Train')
    plt.xlabel('Epochs')
    plt.ylabel(key.replace('_',' ').title())
    plt.legend()
    
    plt.xlim([0,max(history.epoch)])
    
plot_history([('baseline', baseline_history),
             ('smaller', smaller_history),
             ('bigger', bigger_history)])

# %% [markdown]
# ## 3. 과대적합을 방지하기 위한 전략
# ### 가중치 규제하기

# %%
l2_model = keras.models.Sequential([
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                      activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                      activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

l2_model.compile(optimizer='adam',
                loss='binary_crossentropy',
                metrics=['accuracy','binary_crossentropy'])

l2_model_history = l2_model.fit(train_data, train_labels,
                               epochs=20,
                               batch_size=512,
                               validation_data=(test_data, test_labels),
                               verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 5s - loss: 0.5153 - acc: 0.8145 - binary_crossentropy: 0.4744 - val_loss: 0.3716 - val_acc: 0.8767 - val_binary_crossentropy: 0.3279
# Epoch 2/20
#  - 5s - loss: 0.2971 - acc: 0.9088 - binary_crossentropy: 0.2485 - val_loss: 0.3359 - val_acc: 0.8875 - val_binary_crossentropy: 0.2838
# Epoch 3/20
#  - 4s - loss: 0.2479 - acc: 0.9307 - binary_crossentropy: 0.1932 - val_loss: 0.3430 - val_acc: 0.8848 - val_binary_crossentropy: 0.2867
# Epoch 4/20
#  - 4s - loss: 0.2280 - acc: 0.9404 - binary_crossentropy: 0.1698 - val_loss: 0.3643 - val_acc: 0.8774 - val_binary_crossentropy: 0.3048
# Epoch 5/20
#  - 4s - loss: 0.2127 - acc: 0.9481 - binary_crossentropy: 0.1521 - val_loss: 0.3744 - val_acc: 0.8759 - val_binary_crossentropy: 0.3129
# Epoch 6/20
#  - 4s - loss: 0.2011 - acc: 0.9534 - binary_crossentropy: 0.1387 - val_loss: 0.3888 - val_acc: 0.8739 - val_binary_crossentropy: 0.3258
# Epoch 7/20
#  - 4s - loss: 0.1943 - acc: 0.9556 - binary_crossentropy: 0.1305 - val_loss: 0.4129 - val_acc: 0.8700 - val_binary_crossentropy: 0.3484
# Epoch 8/20
#  - 4s - loss: 0.1885 - acc: 0.9574 - binary_crossentropy: 0.1233 - val_loss: 0.4283 - val_acc: 0.8690 - val_binary_crossentropy: 0.3626
# Epoch 9/20
#  - 4s - loss: 0.1839 - acc: 0.9581 - binary_crossentropy: 0.1173 - val_loss: 0.4462 - val_acc: 0.8628 - val_binary_crossentropy: 0.3790
# Epoch 10/20
#  - 5s - loss: 0.1787 - acc: 0.9614 - binary_crossentropy: 0.1111 - val_loss: 0.4553 - val_acc: 0.8649 - val_binary_crossentropy: 0.3873
# Epoch 11/20
#  - 5s - loss: 0.1728 - acc: 0.9644 - binary_crossentropy: 0.1046 - val_loss: 0.4692 - val_acc: 0.8630 - val_binary_crossentropy: 0.4005
# Epoch 12/20
#  - 5s - loss: 0.1695 - acc: 0.9638 - binary_crossentropy: 0.1005 - val_loss: 0.4836 - val_acc: 0.8608 - val_binary_crossentropy: 0.4143
# Epoch 13/20
#  - 5s - loss: 0.1647 - acc: 0.9675 - binary_crossentropy: 0.0951 - val_loss: 0.4967 - val_acc: 0.8607 - val_binary_crossentropy: 0.4270
# Epoch 14/20
#  - 4s - loss: 0.1619 - acc: 0.9684 - binary_crossentropy: 0.0917 - val_loss: 0.5184 - val_acc: 0.8566 - val_binary_crossentropy: 0.4479
# Epoch 15/20
#  - 5s - loss: 0.1610 - acc: 0.9682 - binary_crossentropy: 0.0904 - val_loss: 0.5285 - val_acc: 0.8582 - val_binary_crossentropy: 0.4574
# Epoch 16/20
#  - 5s - loss: 0.1576 - acc: 0.9692 - binary_crossentropy: 0.0857 - val_loss: 0.5398 - val_acc: 0.8544 - val_binary_crossentropy: 0.4678
# Epoch 17/20
#  - 5s - loss: 0.1546 - acc: 0.9704 - binary_crossentropy: 0.0827 - val_loss: 0.5484 - val_acc: 0.8557 - val_binary_crossentropy: 0.4763
# Epoch 18/20
#  - 4s - loss: 0.1547 - acc: 0.9714 - binary_crossentropy: 0.0819 - val_loss: 0.5797 - val_acc: 0.8528 - val_binary_crossentropy: 0.5066
# Epoch 19/20
#  - 4s - loss: 0.1524 - acc: 0.9711 - binary_crossentropy: 0.0790 - val_loss: 0.5656 - val_acc: 0.8546 - val_binary_crossentropy: 0.4917
# Epoch 20/20
#  - 4s - loss: 0.1423 - acc: 0.9779 - binary_crossentropy: 0.0686 - val_loss: 0.5726 - val_acc: 0.8542 - val_binary_crossentropy: 0.4994

# %%
plot_history([('baseline',baseline_history),
             ('l2', l2_model_history)])

# %%
dpt_model = keras.models.Sequential([
    keras.layers.Dense(16, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation='sigmoid')
])

dpt_model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy','binary_crossentropy'])

dpt_model_history = dpt_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# WARNING:tensorflow:From C:\Users\la\Anaconda3\envs\py36\lib\site-packages\tensorflow\python\keras\layers\core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 5s - loss: 0.6058 - acc: 0.6736 - binary_crossentropy: 0.6058 - val_loss: 0.4648 - val_acc: 0.8590 - val_binary_crossentropy: 0.4648
# Epoch 2/20
#  - 4s - loss: 0.4401 - acc: 0.8306 - binary_crossentropy: 0.4401 - val_loss: 0.3359 - val_acc: 0.8832 - val_binary_crossentropy: 0.3359
# Epoch 3/20
#  - 5s - loss: 0.3427 - acc: 0.8817 - binary_crossentropy: 0.3427 - val_loss: 0.2939 - val_acc: 0.8882 - val_binary_crossentropy: 0.2939
# Epoch 4/20
#  - 8s - loss: 0.2837 - acc: 0.9094 - binary_crossentropy: 0.2837 - val_loss: 0.2785 - val_acc: 0.8890 - val_binary_crossentropy: 0.2785
# Epoch 5/20
#  - 5s - loss: 0.2443 - acc: 0.9216 - binary_crossentropy: 0.2443 - val_loss: 0.2820 - val_acc: 0.8880 - val_binary_crossentropy: 0.2820
# Epoch 6/20
#  - 4s - loss: 0.2082 - acc: 0.9357 - binary_crossentropy: 0.2082 - val_loss: 0.3037 - val_acc: 0.8842 - val_binary_crossentropy: 0.3037
# Epoch 7/20
#  - 4s - loss: 0.1849 - acc: 0.9441 - binary_crossentropy: 0.1849 - val_loss: 0.3098 - val_acc: 0.8847 - val_binary_crossentropy: 0.3098
# Epoch 8/20
#  - 5s - loss: 0.1648 - acc: 0.9486 - binary_crossentropy: 0.1648 - val_loss: 0.3267 - val_acc: 0.8803 - val_binary_crossentropy: 0.3267
# Epoch 9/20
#  - 5s - loss: 0.1489 - acc: 0.9534 - binary_crossentropy: 0.1489 - val_loss: 0.3428 - val_acc: 0.8795 - val_binary_crossentropy: 0.3428
# Epoch 10/20
#  - 5s - loss: 0.1342 - acc: 0.9578 - binary_crossentropy: 0.1342 - val_loss: 0.3695 - val_acc: 0.8793 - val_binary_crossentropy: 0.3695
# Epoch 11/20
#  - 5s - loss: 0.1203 - acc: 0.9634 - binary_crossentropy: 0.1203 - val_loss: 0.3794 - val_acc: 0.8769 - val_binary_crossentropy: 0.3794
# Epoch 12/20
#  - 4s - loss: 0.1103 - acc: 0.9649 - binary_crossentropy: 0.1103 - val_loss: 0.4220 - val_acc: 0.8776 - val_binary_crossentropy: 0.4220
# Epoch 13/20
#  - 5s - loss: 0.1012 - acc: 0.9680 - binary_crossentropy: 0.1012 - val_loss: 0.4405 - val_acc: 0.8767 - val_binary_crossentropy: 0.4405
# Epoch 14/20
#  - 4s - loss: 0.0936 - acc: 0.9711 - binary_crossentropy: 0.0936 - val_loss: 0.4575 - val_acc: 0.8774 - val_binary_crossentropy: 0.4575
# Epoch 15/20
#  - 5s - loss: 0.0868 - acc: 0.9734 - binary_crossentropy: 0.0868 - val_loss: 0.4481 - val_acc: 0.8742 - val_binary_crossentropy: 0.4481
# Epoch 16/20
#  - 4s - loss: 0.0825 - acc: 0.9750 - binary_crossentropy: 0.0825 - val_loss: 0.4795 - val_acc: 0.8750 - val_binary_crossentropy: 0.4795
# Epoch 17/20
#  - 4s - loss: 0.0768 - acc: 0.9766 - binary_crossentropy: 0.0768 - val_loss: 0.4975 - val_acc: 0.8736 - val_binary_crossentropy: 0.4975
# Epoch 18/20
#  - 5s - loss: 0.0734 - acc: 0.9779 - binary_crossentropy: 0.0734 - val_loss: 0.5269 - val_acc: 0.8752 - val_binary_crossentropy: 0.5269
# Epoch 19/20
#  - 4s - loss: 0.0723 - acc: 0.9772 - binary_crossentropy: 0.0723 - val_loss: 0.5494 - val_acc: 0.8744 - val_binary_crossentropy: 0.5494
# Epoch 20/20
#  - 4s - loss: 0.0663 - acc: 0.9802 - binary_crossentropy: 0.0663 - val_loss: 0.5551 - val_acc: 0.8744 - val_binary_crossentropy: 0.5551

# %%
plot_history([('baseline', baseline_history),
              ('dropout', dpt_model_history),
             ('l2', l2_model_history)])

# %% [markdown]
# ## 신경망에서 과대적합을 방지하기 위해 가장 널리 사용하는 방법은 다음과 같습니다:
#
# - 더 많은 훈련 데이터를 모읍니다.
# - 네트워크의 용량을 줄입니다.
# - 가중치 규제를 추가합니다.
# - 드롭아웃을 추가합니다.
# - 이 문서에서 다루지 않은 중요한 방법 두 가지는 데이터 증식(data-augmentation)과 배치 정규화(batch normalization)입니다.
