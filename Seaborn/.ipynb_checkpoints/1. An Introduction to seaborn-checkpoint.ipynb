# %% [markdown]
# # Seaborn 0.9.0 Version
# # Date : 2019.4.28

# %% [markdown]
# ## An Introduction to seaborn
# URL : https://seaborn.pydata.org/introduction.html

# %% [markdown]
# It is built on top of matplotlib and closely integrated with pandas data structures.
#
# - A dataset-oriented API for examining relationships between multiple variables
# - Specialized support for using categorical variables to show observations or aggregate statistics
# - Options for visualizing univariate or bivariate distributions and for comparing them between subsets of data
# - Automatic estimation and plotting of linear regression models for different kinds dependent variables
# - Convenient views onto the overall structure of complex datasets
# - High-level abstractions for structuring multi-plot grids that let you easily build complex visualizations
# - Concise control over matplotlib figure styling with several built-in themes
# - Tools for choosing color palettes that faithfully reveal patterns in your data

# %%
import seaborn as sns

# %%
sns.set()
tips = sns.load_dataset('tips')
# load_dataset list
# anscombe,attention, brain_networks, car_crashes iris, tips, titanic etc
# url : https://github.com/mwaskom/seaborn-data

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set()
tips = sns.load_dataset("tips")
sns.relplot(x="total_bill",y="tip", col="time", 
            hue="smoker", style="smoker", size="size",
            data=tips)
# relationship plot

# %%
sns.set()
tips = sns.load_dataset("tips")
sns.relplot(x="total_bill",y="tip", 
            hue="smoker", size="size",
            data=tips)
# relationship plot

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
for i in [col for col in tips.columns if tips[col].dtypes != 'float64']:
    print(i,'column\'s unique',tips[i].unique())
# Out:
# sex column's unique [Female, Male]
# Categories (2, object): [Female, Male]
# smoker column's unique [No, Yes]
# Categories (2, object): [No, Yes]
# day column's unique [Sun, Sat, Thur, Fri]
# Categories (4, object): [Sun, Sat, Thur, Fri]
# time column's unique [Dinner, Lunch]
# Categories (2, object): [Dinner, Lunch]
# size column's unique [2 3 4 1 6 5]

# %% [markdown]
# ## API abstraction across visualizations

# %%
dots = sns.load_dataset('dots')
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
dots.dtypes
# Out:
# align           object
# choice          object
# time             int64
# coherence      float64
# firing_rate    float64
# dtype: object

# %%
for i in [col for col in dots.columns if col != 'firing_rate']:
    print(i,'column\'s unique',dots[i].unique())
# Out:
# align column's unique ['dots' 'sacc']
# choice column's unique ['T1' 'T2']
# time column's unique [ -80  -60  -40  -20    0   20   40   60   80  100  120  140  160  180
#   200  220  240  260  280  300  320  340  360  380  400  420  440  460
#   480  500  520  540  560  580  600  620  640  660  680  700  720 -600
#  -580 -560 -540 -520 -500 -480 -460 -440 -420 -400 -380 -360 -340 -320
#  -300 -280 -260 -240 -220 -200 -180 -160 -140 -120 -100]
# coherence column's unique [ 0.   3.2  6.4 12.8 25.6 51.2]

# %%
sns.relplot(x='time', y='firing_rate', col='align',
           hue='choice', size='coherence', style='choice',
           facet_kws=dict(sharex=False),
           kind='line', legend='full', data=dots)

# %%
sns.relplot(x='time', y='firing_rate', col='align',
           hue='choice', style='choice',
           facet_kws=dict(sharex=False),
           kind='line', legend='full', data=dots)
#skip size parameter

# %%
sns.relplot(x='time', y='firing_rate', col='align',
           hue='choice', size='coherence', style='choice',
           facet_kws=dict(sharex=False),
            legend='full', data=dots) 
#skip kind parameter

# %%
sns.relplot(x='time', y='firing_rate', col='align',
           hue='choice', size='coherence',
           kind='line', legend='full', data=dots)
#skip (style & facet_kws) parameter

# %% [markdown]
# ## Statistical estimation and error bars

# %%
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
fmri.dtypes
# Out:
# subject       object
# timepoint      int64
# event         object
# region        object
# signal       float64
# dtype: object

# %%
for i in [col for col in fmri.columns if col != 'signal']:
    print(i,'column\'s unique',fmri[i].unique())
# Out:
# subject column's unique ['s13' 's5' 's12' 's11' 's10' 's9' 's8' 's7' 's6' 's4' 's3' 's2' 's1' 's0']
# timepoint column's unique [18 14 17  9 16 15  0 13 12 11 10  3  7  8  2  6  5  4  1]
# event column's unique ['stim' 'cue']
# region column's unique ['parietal' 'frontal']

# %%
sns.relplot(x='timepoint', y='signal', col='region',
           hue='event', style='event',
           kind='line', data=fmri)

# %%
sns.lmplot(x='total_bill', y='tip', col='time',
          hue='smoker',data=tips)

# %%
sns.lmplot(x='total_bill', y='tip', 
          hue='smoker',data=tips)

# %% [markdown]
# ## Specialized categorical plots
#
# 1 numeric 1(or more) categoric vairables

# %%
sns.catplot(x='day', y='total_bill', hue='smoker', kind='swarm', data=tips)

# %%
sns.catplot(y='day', x='total_bill', hue='smoker', kind='swarm', data=tips)

# %%
sns.catplot(x='day', y='total_bill', hue='smoker',
            kind='violin', split=True, data=tips)

# %%
sns.catplot(x='day', y='total_bill', hue='smoker',
            kind='violin', data=tips)

# %%
sns.catplot(x='day', y='total_bill', hue='smoker',
            kind='bar', data=tips)

# %% [markdown]
# ## Figure-level and axes-level functions

# %%
import matplotlib.pyplot as plt
f, axes = plt.subplots(1,2, sharey=True, figsize=(6,4))
sns.boxplot(x='day', y='tip', data=tips, ax=axes[0])
sns.scatterplot(x='total_bill', y='tip', hue='day', data=tips, ax=axes[1])

# %%
sns.relplot(x='time', y='firing_rate', col='align',
           hue='choice', size='coherence', style='choice',
           height=4.5, aspect=2/3,
           facet_kws=dict(sharex=False),
           kind='line', legend='full', data=dots)

# %%
sns.relplot(x='time', y='firing_rate', col='align',
           hue='choice', size='coherence', style='choice',
           height=4.5, facet_kws=dict(sharex=False),
           kind='line', legend='full', data=dots)

# %% [markdown]
# ## Visualizing dataset structure

# %%
iris = sns.load_dataset('iris')
sns.jointplot(x='sepal_length', y='petal_length', data=iris)

# %%
sns.pairplot(data=iris, hue='species')

# %% [markdown]
# ## Customizing plot appearance

# %%
sns.set()
sns.relplot(x='total_bill', y='tip', col='time',
           hue='smoker', style='smoker', size='size',
           data=tips)

# %%
sns.set(style='ticks', palette='muted')
sns.relplot(x='total_bill', y='tip', col='time',
           hue='smoker', style='smoker', size='size',
           data=tips)

# %%
sns.set(style='ticks')
sns.relplot(x='total_bill', y='tip', col='time',
           hue='smoker', style='smoker', size='size',
           data=tips)

# %%
sns.relplot(x='total_bill', y='tip', col='time',
           hue='size', style='smoker', size='size',
            palette='YlGnBu', markers=['D','o'], sizes=(10,125),
            edgecolor='.2', linewidth=.5, alpha=.75,            
           data=tips)

# %%
sns.relplot(x='total_bill', y='tip', col='time',
           hue='size', style='smoker', size='size',
            palette='YlGnBu', markers=['D','o'], sizes=(10,125),
            edgecolor='.2', linewidth=.5,   
           data=tips)

# %%
sns.relplot(x='total_bill', y='tip', col='time',
           hue='size', style='smoker', size='size',
           data=tips)

# %%
g = sns.catplot(x="total_bill", y="day", hue="time",
                height=3.5, aspect=1.5,
                kind="box", legend=False, data=tips)
g.add_legend(title='Meal')
g.set_axis_labels('Total bill($)','')
g.set(xlim=(0,60), yticklabels=['Thursday','Friday','Saturday','Sunday'])
#g.despine(trim=True)

# %%
g = sns.catplot(x="total_bill", y="day", hue="time",
                height=3.5, aspect=1.5,
                kind="box", legend=False, data=tips)
g.add_legend(title='Meal')
g.set_axis_labels('Total bill($)','')
g.set(xlim=(0,60), yticklabels=['Thursday','Friday','Saturday','Sunday'])
g.despine(trim=True)
g.fig.set_size_inches(6.5, 3.5)
g.ax.set_xticks([5,15,25,35,45,55], minor=True)
plt.setp(g.ax.get_yticklabels(), rotation=30)
# Out:
# [None, None, None, None, None, None, None, None]
